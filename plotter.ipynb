# %%
import numpy as np

a = np.load('array.npy')

# %%
# plot the array
import matplotlib.pyplot as plt
plt.plot(a.T)

# %%
a.T
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.07745573,  0.04480264,  0.04561496, ...,  0.06111464,
#          0.04959552,  0.05125442],
#        [ 0.15898075,  0.06393868,  0.08165087, ...,  0.11180316,
#          0.07249991,  0.10566638],
#        ...,
#        [ 2.85929822,  0.8740411 ,  1.14537897, ..., -2.07424008,
#         -0.06457815,  0.24828765],
#        [ 2.82112385,  0.86507371,  1.09933171, ..., -2.080686  ,
#         -0.04720839,  0.24506972],
#        [ 2.78791723,  0.86486503,  1.07058285, ..., -2.07351871,
#         -0.01559188,  0.24098896]])
